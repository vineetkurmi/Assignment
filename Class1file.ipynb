# %% [markdown]
# # **Using NumPy**
#
# Once you've installed NumPy you can import it as a library:

# %%
import numpy as np

# %% [markdown]
# Numpy has many built-in functions and capabilities. We won't cover them all but instead we will focus on some of the most important aspects of Numpy: vectors,arrays,matrices, and number generation. Let's start by discussing arrays.
#
# # Numpy Arrays
#
# NumPy arrays are the main way we will use Numpy throughout the course. Numpy arrays essentially come in two flavors: vectors and matrices. Vectors are strictly 1-d arrays and matrices are 2-d (but you should note a matrix can still have only one row or one column).
#
# Let's begin our introduction by exploring how to create NumPy arrays.
#
# ## Creating NumPy Arrays
#
# ### From a Python List
#
# We can create an array by directly converting a list or list of lists:

# %%
l = [10,20,30,40,50]  # 1D Array
array = np.array(l)
print(array)
print(array.mean())

# %% [markdown]
# Lets create a matrix using list

# %%
a = [
    [1,2,3],
    [4,5,6],
    [7,8,9]
]
matrix = np.array(a)
matrix

# %% [markdown]
# Now lets see how matrix looks like using numpy arrays

# %% [markdown]
# ## Built-in Methods
#
# there are lots of build in methods to create an array lets create some and see
#
# np.zeros(), np.ones(), np.full()
#
# np.arange(), np.linspace()
#
# np.eye()

# %%
# 1.) np.zeros() for 1D

np.zeros(4)

# %%
# np.zeros() for matrix
# rows & columns

np.zeros([3,4])

# %%
# 2.) np.ones() for 1D

np.ones(4)

# %%
# np.ones() for matrix
# rows & columns

np.ones([3,4])

# %%
# 3.) np.full() for 1D

np.full(5,7)

# %%
# np.full() for matrix

np.full([3,4],5)

# %%
# 4.) np.arange()

arr = np.arange(0,10,2)
arr

# %%
# 5.) np.linspace()  start = 0,  stop = 1,  value = 5

np.linspace(0,1,5)

# %%
# 6.) np.eye()  Identity matrix

np.eye(4)

# %%
# np.random.rand() # rows , coumns

np.random.rand(2,3)

# %%
# np.random.randit(start,stop,(rows,column))

np.random.randint(0,10,(3,3))

"""
randit  -> 1 se 20 ke beech ki random values
se matrix create karega
"""

# %% [markdown]
# arange → step-based values
#
# linspace → fixed number of values
#
# eye → identity matrix
#
# rand → random floats (0–1)
#
# randint → random integers in a range
#
# randn → random values from bell curve distribution
